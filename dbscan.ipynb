# %% [markdown]
# <a href="https://colab.research.google.com/github/ash030889/Machine-Learning/blob/main/dbscan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/Mall_Customers.csv')

# %%
df = data.drop(['CustomerID'], axis = 1)

# %%
df['Gender'] = df['Gender'].apply({'Female' : 0, 'Male' : 1}.get)

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0       1   19                  15                      39
# 1       1   21                  15                      81
# 2       0   20                  16                       6
# 3       0   23                  16                      77
# 4       0   31                  17                      40

# %%
from sklearn.cluster import DBSCAN
cluster = DBSCAN(eps = 12.5, min_samples = 4).fit(df)
DBSCAN_dataset = df.copy()
DBSCAN_dataset.loc[ : ,'cluster'] = cluster.labels_

# %%
DBSCAN_dataset.cluster.value_counts().to_frame()
# Out:
#     cluster
#  0      112
#  2       34
#  3       24
# -1       18
#  1        8
#  4        4
